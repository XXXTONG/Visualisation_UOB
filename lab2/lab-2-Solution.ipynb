# %% [markdown]
# # Visualisation
# # Lab 2 - Logarithmic Scales

# %% [markdown]
# # Tutorial Section

# %%
# Here we import all packages we need.

# This is a package for handling and manipulating data.
import pandas as pd

# This is the standard package for plotting.
from matplotlib import pyplot as plt 

# Seaborn is build on matplotlib.
# It is more comfortable to use than pure matplotlib.
import seaborn as sns

# Numpy helps as handling arrays of numbers
import numpy as np

# This computes the normal distribution's PDF
def normpdf(x, mean, sd):
    var = float(sd)**2
    denom = (2*np.pi*var)**.5
    num = np.exp(-((x)-(mean))**2/(2*var))
    return num/denom

# %% [markdown]
# ## Logarithmic Scales

# %%
# We load the diamonds dataset
planets = sns.load_dataset("planets")
planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
# Let's make a scaterplot
sns.scatterplot(data=planets,x='mass',y='orbital_period')

# You can show multiple plots in one cell by calling this inbetween plots
plt.show()

# The planets are very cramped into the lower left corner
# We will try logarithmic scales
sns.scatterplot(data=planets,x='mass',y='orbital_period')
plt.yscale('log')

plt.show()
# logarithmic scales on both axis
sns.scatterplot(data=planets,x='mass',y='orbital_period')
plt.yscale('log')
plt.xscale('log')

# %% [markdown]
# ## Lineplots
# You can make lineplots like this:

# %%
# We load the flights dataset
flights = sns.load_dataset("flights")

# Let's average over all months of each year
flights= flights.groupby('year').mean()

sns.lineplot(data=flights, x='year', y='passengers')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %% [markdown]
# ---
#
# # Excercises

# %% [markdown]
# # Excercise 1
# The file `datasets.csv` contains six datasets of corresponding `x` and `y` values.
# The `y` values have been calculated from the `x` values using different functions.
# * Two of the datasets use a quadratic function $y=ax^2$.
# * Two of the datasets use an exponential function $y=ab^x$.
# * One of the datasets uses a cubic function $y=ax^3$.
# * One dataset uses a function of the form $\frac{a}{x}$
#
# Which one of the datasets belongs to which function?
# Please derive the solution graphically.

# %%
# We read the file
data=pd.read_csv('datasets.csv')

# Please implement

# %% [markdown]
# ## Solution

# %%
data=pd.read_csv('datasets.csv')

# You can use this to make a lineplot
sns.lineplot(data=data,x='x', y='y', hue= 'set')
#plt.xscale('log')
#plt.yscale('log')
sns.despine()

# %%
data=pd.read_csv('datasets.csv')

sns.lineplot(data=data,x='x', y='y', hue= 'set')
plt.xscale('log')
plt.yscale('log')
sns.despine()

# %% [markdown]
# Sets`f` and `c` belong to the quadratic functions, because they correspond to straight lines in the log-log plot having the same slope.
# Set `b` belongs to the cubic function. Because it is a straight line.
# Set `e` belongs to $a/x$.
# Because it is a straight descending line.

# %%
data=pd.read_csv('datasets.csv')

sns.lineplot(data=data,x='x', y='y', hue= 'set')
plt.yscale('log')
sns.despine()

# %% [markdown]
# Sets `a` and `d` belong to the exponential function because they show as straight line in the log-linear plot.

# %% [markdown]
# # Excercise 2
# You track the development of four viral online videos as they accumulate views.
# The file `videos.csv` contains the time in hours (`time (h)` column) since you started logging the accumulated views (`views` column).
# The name of the video is contained in the `video` column.
#
# Which type of mathematical function describes the accumulation of views for each video?
# Considering that the videos continue to be viewed and shared in the same way, which video will have the most views after 1000 hours?
# Which will have the second, third, and fourth most views?
# Can you derive the answer in a purely visual way by making an adequate plot and mentally extrapolating?

# %%
# We read the file 
videos=pd.read_csv('videos.csv')

# Please implement.

# %% [markdown]
# ## Solution

# %%
sns.lineplot(data=videos,x='hours', y='views', hue= 'video')
#plt.yscale('log')
sns.despine()

# %%
sns.lineplot(data=videos,x='hours', y='views', hue= 'video')
plt.yscale('log')
sns.despine()

# %% [markdown]
# The order of views will be `Cats`, `kittens`, `puppys`, `pandas`.
# This can be determined by extrapolating the lines in the log-linear plot.
# All videos have exponential growth because they show as straight lines in the log-linear plot.

# %% [markdown]
# # Excercise 3
# Take a plot you made in Exercise 2 and turn it into a figure that tries to follow the design principles discussed in the lecture videos of week 2. Can you tell a story using the data?
# There are many ways to achieve this. Also, have a look at last weeks notebook to see how you can modify the appearance of the plot. Some modifications are best made using different tools other than matplotlib and seaborn.
# You can save the plot and then modify it using a vector graphics program, such as [inkscape](https://inkscape.org/)  (have a look at tutorials [here](https://inkscape.org/learn/) or [here for editing pdfs](https://www.youtube.com/watch?v=m5uh_hBfmCk)) or adobe illustrator. You can also use power point or a similar program if you like.
#
# If you would like to have feedback you can submit the figure as a pdf in canvas.
