# %% [markdown]
# # Visualisation
# # Lab 0 - Raster graphics and vector graphics
# If jupyter notebooks are new for you, have a look at this [tutorial](https://medium.com/velotio-perspectives/the-ultimate-beginners-guide-to-jupyter-notebooks-6b00846ed2af).

# %%
# Here we import all packages we need.

# This is a package for handling and manipulating data.
import pandas as pd

# This is the standard package for plotting.
from matplotlib import pyplot as plt 

# Seaborn is build on matplotlib.
# It is more confortable to use than pure matplotlib.
import seaborn as sns

import numpy as np

# %%
# This loads the 'anscombe' example dataset.
anscombe = sns.load_dataset("anscombe")
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
sns.scatterplot(data=anscombe, x = 'x', y = 'y', hue = 'dataset')
# Out:
# <AxesSubplot: xlabel='x', ylabel='y'>

# %% [markdown]
# # Exercise 1:
# Use ['plt.savefig'](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.savefig.html) to save the figure as '.png', 'jgp', 'pdf', 'svg' file.

# %% [markdown]
# # Exercise 2:
# Open the resulting files using an image viewer of your choice. You can also use your browser.
# Zoom into the top left corner. Do you see differences?

# %% [markdown]
# # Exercise 3:
# Use ['plt.imread'](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imread.html) to save the figure as '.png', 'jgp', 'pdf', 'svg' file.
# The function will return a 3D tensor. How should we interpret the tensor?
# Can you use ['plt.imshow'](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imshow.html) to look at different 2D slices of the tensor?
